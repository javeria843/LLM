# %%
# Python file create karna
file_name = "secret_key.py"

# Apni secret key ko is file mein likhna
with open(file_name, 'w') as f:
    f.write('openai_key = "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"\n')

print(f"{file_name} file successfully created!")
# Out:
# secret_key.py file successfully created!

# %%
print("Loaded API key:", openai_key)
# Out:
# Loaded API key: sk-proj-xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
from secret_key import openai_key
import os

# Set the OpenAI API key from the secret_key file
os.environ["OPENAI_API_KEY"] = openai_key

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.streamlit',
#  '.vscode',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'imdb_top_1000.csv',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NLP.ipynb',
#  'NLPPROJECT.ipynb',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c6a16deb-e222-11ee-a9c9-70d82397343d}.TM.blf',
#  'NTUSER.DAT{c6a16deb-e222-11ee-a9c9-70d82397343d}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c6a16deb-e222-11ee-a9c9-70d82397343d}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'secret_key.py',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
# ...

# %%
from langchain.llms import OpenAi
lls= OpenAi(temperature=0.6)
restaurent= lls("i wnat to open a restaurent with best pakistani foods")
print(restaurent)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.llms import OpenAi
#       2 lls= OpenAi(temperature=0.6)
#       3 restaurent= lls("i wnat to open a restaurent with best pakistani foods")
#
# File E:\Lib\site-packages\langchain\llms\__init__.py:545, in __getattr__(name)
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     547     # If not in interactive env, raise warning.
#     548     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
# !pip install langchain_community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 685.7 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 882.6 kB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 834.6 kB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 834.6 kB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 773.5 kB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 773.5 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.8/2.5 MB 861.7 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 861.7 kB/s eta 0:00:01
# ...

# %%
# !pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/662.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/662.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/662.0 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/662.0 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/662.0 kB ? eta -:--:--
#    ------------------------------ ------- 524.3/662.0 kB 822.5 kB/s eta 0:00:01
#    -------------------------------------- 662.0/662.0 kB 726.3 kB/s eta 0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [distro]
#    ------------- -------------------------- 1/3 [distro]
#    ------------- -------------------------- 1/3 [distro]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
# ...

# %%
from langchain.llms import OpenAI  # Import capital "AI"
lls = OpenAI(temperature=0.6)  # Initialize with the corrected class name
restaurant = lls("I want to open a restaurant with the best Pakistani foods,suggest me good food ")  # Fixed typo in 'restaurant'
print(restaurant)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 from langchain.llms import OpenAI  # Import capital "AI"
#       2 lls = OpenAI(temperature=0.6)  # Initialize with the corrected class name
# ----> 3 restaurant = lls("I want to open a restaurant with the best Pakistani foods,suggest me good food ")  # Fixed typo in 'restaurant'
#       4 print(restaurant)
#
# File E:\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File E:\Lib\site-packages\langchain_core\language_models\llms.py:1315, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1308     msg = (
# ...

# %%
print(restaurant)

# %%
from langchain.prompts import PromptTemplate
prompt_template_name= PromptTemplate(
    input_variables=["cuisines"],
    template="i want to open  arestaurent for {cuisine} food, sugest  a fancy name for this"
)
prompt_template_name.format(cuisine="italian")
# Out:
# 'i want to open  arestaurent for italian food, sugest  a fancy name for this'
